# %% [markdown]
# # Advance Histograph

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import scipy

# %%
tips_df=sns.load_dataset("tips")
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.figure(figsize=(14,9))
sns.set()
sns.distplot(tips_df["total_bill"],color="r")
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3100\6023689.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df["total_bill"],color="r")
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
tips_df.total_bill.sort_values()
# Out:
# 67      3.07
# 92      5.75
# 111     7.25
# 172     7.25
# 149     7.51
#        ...
# 182    45.35
# 156    48.17
# 59     48.27
# 212    48.33
# 170    50.81
# Name: total_bill, Length: 244, dtype: float64

# %%
bins=[1,5,10,15,20,25,30,35,40,45,50,55]

plt.figure(figsize=(14,9))
sns.set()
plt.xticks(bins)
sns.distplot(tips_df["total_bill"],color="r",bins=bins)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3100\2314102330.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df["total_bill"],color="r",bins=bins)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
bins=[1,5,10,15,20,25,30,35,40,45,50,55]

plt.figure(figsize=(14,9))
sns.set()
plt.xticks(bins)
sns.distplot(tips_df["total_bill"],color="r",bins=bins,
            hist_kws={'color':'m','edgecolor':'r','linewidth':5,'alpha':0.9})
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3100\1112567497.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df["total_bill"],color="r",bins=bins,
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
bins=[1,5,10,15,20,25,30,35,40,45,50,55]

plt.figure(figsize=(14,9))
sns.set()
plt.xticks(bins)
sns.distplot(tips_df["total_bill"],color="r",bins=bins,
            hist_kws={'color':'m','edgecolor':'r','linewidth':5,'alpha':0.9},
            
             kde_kws={'color':'r','linewidth':5,'alpha':0.9}
            )
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3100\221466701.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df["total_bill"],color="r",bins=bins,
# <Axes: xlabel='total_bill', ylabel='Density'>
