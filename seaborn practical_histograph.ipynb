# %% [markdown]
# # histograph in seaborn using distplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats

# %%
tips_df=sns.load_dataset("tips")
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.distplot(tips_df['size'])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2452\3999728182.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df['size'])
# <Axes: xlabel='size', ylabel='Density'>

# %%
sns.distplot(tips_df['tip'])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2452\4114240922.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df['tip'])
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sns.distplot(tips_df['total_bill'])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2452\3759225478.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df['total_bill'])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips_df['size'],bins=10)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2452\896838812.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df['size'],bins=10)
# <Axes: xlabel='size', ylabel='Density'>

# %%
sns.distplot(tips_df['total_bill'],bins= 244) # this line is called as kernal density extiater whihc is special function in displot or dostplot in seaborn
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2452\2689407736.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df['total_bill'],bins= 244) # this line is called as kernal density extiater whihc is special function in displot or dostplot in seaborn
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips_df['total_bill'],color='r',vertical=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2452\546679202.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df['total_bill'],color='r',vertical=True)
# <Axes: xlabel='Density', ylabel='total_bill'>

# %%
sns.distplot(tips_df['total_bill'],color='r',axlabel="Total Bill")
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2452\1499467657.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df['total_bill'],color='r',axlabel="Total Bill")
# <Axes: xlabel='Total Bill', ylabel='Density'>

# %%
sns.distplot(tips_df['total_bill'],color='r',label="total bill")
plt.legend()
plt.title("histogram of Totalbill",fontsize=20)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2452\3400543765.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df['total_bill'],color='r',label="total bill")
# Text(0.5, 1.0, 'histogram of Totalbill')
